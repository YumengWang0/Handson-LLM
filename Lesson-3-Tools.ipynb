# %% [markdown]
# ## 2. Prompt Engineering & Inference
# #### Zero-shot / Few-shot prompting
#
# - zero-shot: directly output from LLM
#     - template:
#
# - Few-shot: with examples in the prompt
#     - template:
#
# ----
# #### Chain-of-Thought (CoT)
#
# - Act and Reasoning
#     - template:
#
#
#
#
#
#
# ----
# #### Prompt templates
#
# -
#
#
# ----
# #### Greedy vs Beam Search vs Sampling (top-k, top-p)
#
#
# -
#
# ----
# #### Temperature and decoding strategies
#
# ---
#
#
#
#
# ## LLM template usually used in the examples
